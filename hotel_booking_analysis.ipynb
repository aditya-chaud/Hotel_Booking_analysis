# %%
#This is a practice for exploratory data analysis in python using python libraries: pandas, matplotlib, seaborn. The dataset is from Kaggle named: Hotel Booking
#Here, I have analysed for why there high cancellation rate of hotels and what factors affect the cancellation of the hotel
#from starting to end.

# %%
#Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#Loading the dataset
df=pd.read_csv('hotel_booking.csv')

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.shape
# Out:
# (119390, 36)

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#removing the columns that tells the information about the customer to give privacy.
df.drop(['name','email','phone-number','credit_card'],axis=1,inplace=True)

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
#converting the data type of 'reservation_status_date' from object to date
df['reservation_status_date']=pd.to_datetime(df['reservation_status_date'])

# %%
df.dtypes
# Out:
# hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                 float64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#since agent and company has many missing values, if we drop the rows of missing values 
#then we would have very less data to analyse. so we have to drop the agent and company column
df=df.drop(['agent','company'],axis=1)

# %%
df.shape
# Out:
# (119390, 30)

# %%
df.isnull().sum()
# Out:
# hotel                               0
# is_canceled                         0
# lead_time                           0
# arrival_date_year                   0
# arrival_date_month                  0
# arrival_date_week_number            0
# arrival_date_day_of_month           0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            4
# babies                              0
# meal                                0
# country                           488
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# reserved_room_type                  0
# assigned_room_type                  0
# booking_changes                     0
# deposit_type                        0
# days_in_waiting_list                0
# customer_type                       0
# ...

# %%
#now dropping the rows with missing values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (118898, 30)

# %%
df.isnull().sum()
#now not any null values in the dataframe
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.shape
# Out:
# (118898, 30)

# %%
#now removing outliers in adr(average daily rate) column where min is in -ve value and max is too high ie. 5400
#also in children, adults, babies
df=df[(df['adults']<20)&(df['children']<8)&(df['babies']<8)&(df['adr'] > 0) & (df['adr'] < 5000)]

# %%
# ppdf=df.copy()
# ppdf=ppdf[(ppdf['adults']<20)&(ppdf['children']<8)&(ppdf['babies']<8)&(ppdf['adr'] > 0) & (ppdf['adr'] < 5000)]
#this filters the rows with given conditions to remove outliers
#just for checking

# %%
df.shape
# Out:
# (116955, 30)

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  116955.000000  116955.000000      116955.000000
# mean        0.375768     105.378701        2016.161464
# std         0.484323     106.945084           0.706501
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      19.000000        2016.000000
# 50%         0.000000      71.000000        2016.000000
# 75%         1.000000     162.000000        2017.000000
# max         1.000000     709.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             116955.000000              116955.000000
# mean                  27.138173                  15.805156
# std                   13.561081                   8.783137
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# ...

# %%
#data analysis and visualization

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2                    July                        27
# 3                    July                        27
# ...

# %%
n=df.copy()

# %%
n.shape
# Out:
# (116955, 30)

# %%
n
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2                    July                        27
# 3                    July                        27
# ...

# %%
cancel_percent=n['is_canceled'].value_counts(normalize=True)

# %%
#series with unique values of the is_canceled column as index
cancel_percent
# Out:
# 0    0.624232
# 1    0.375768
# Name: is_canceled, dtype: float64

# %%
#here 37 percent of total reservation has been cancelled which is a lot for business

# %%
#in all hotels
#specifying canceled and not_canceled for the two unique values in is_canceled column of n dataframe as two bars in the bargraph
#cancel_percent specifies the height of the bargraph, in edgecolor 1 defines the blue color and width defines the width of the bar
plt.bar(['not canceled','canceled'],cancel_percent,edgecolor='1',width=0.7)
plt.title("Resevation status count in percent")
plt.ylabel("percent")
# Out:
# Text(0, 0.5, 'percent')

# %%
#finding the total percentage of each hotels ie  city hotel and resort hotel which is 66% and 33% respectively,
#as series that is stored in hotel_percent
hotel_percent=n['hotel'].value_counts(normalize=True)

# %%
hotel_percent
# Out:
# City Hotel      0.66777
# Resort Hotel    0.33223
# Name: hotel, dtype: float64

# %%
plt.bar(["Cty hotel","Resort Hotel"],hotel_percent)
plt.title("Number of hotels in percent")
plt.ylabel("percent")
# Out:
# Text(0, 0.5, 'percent')

# %%
#finding which hotel's cancellation ratio is higher
sns.countplot(data=n,x='hotel',hue="is_canceled")
plt.title("Reservation status in two hotels")

#city hotel's ratio is bigger
# Out:
# Text(0.5, 1.0, 'Reservation status in two hotels')

# %%
#finding the total cancellation of two hotels
cancel_counts=n['is_canceled'].value_counts()

# %%
cancel_counts
# Out:
# 0    73007
# 1    43948
# Name: is_canceled, dtype: int64

# %%
#finding the total counts in each hotel and then find the ratio of cancellation:canceled/not-canceled of a hotel
#City Hotel
city_hotel=n[n['hotel']=='City Hotel']
resort_hotel=n[n['hotel']=='Resort Hotel']
cancel_counts_city_hotel=city_hotel['is_canceled'].value_counts()
cancel_counts_resort_hotel=resort_hotel['is_canceled'].value_counts()
print(cancel_counts_city_hotel)
print(cancel_counts_resort_hotel)
# Out:
# 0    45145
# 1    32954
# Name: is_canceled, dtype: int64
# 0    27862
# 1    10994
# Name: is_canceled, dtype: int64

# %%
#ratio of cancellation of City hotel: ratio=canceled/not-canceled
cancel_ratio_city_hotel=cancel_counts_city_hotel[1]/cancel_counts_city_hotel[0]
print(cancel_ratio_city_hotel)
# Out:
# 0.7299590209325507

# %%
#ratio of cancellation of Resort hotel: ratio=canceled/not-canceled
cancel_ratio_resort_hotel=cancel_counts_resort_hotel[1]/cancel_counts_resort_hotel[0]
print(cancel_ratio_resort_hotel)
# Out:
# 0.3945876103653722

# %%
#series of cancel_counts of each hotel
#cancel_counts_resort_hotel
cancel_counts_city_hotel
# Out:
# 0    45145
# 1    32954
# Name: is_canceled, dtype: int64

# %%
#calculating the percentage of cancellation of city hotel
cancel_percent_city_hotel=city_hotel['is_canceled'].value_counts(normalize=True)

# %%
cancel_percent_city_hotel
# Out:
# 0    0.578048
# 1    0.421952
# Name: is_canceled, dtype: float64

# %%
#calculating the percentage of cancellation of Resort hotel
#the first line filters the dataframe with row where the hotels = Resort Hotel only 
resort_hotel=n[n['hotel']=='Resort Hotel']
cancel_percent_resort_hotel=resort_hotel['is_canceled'].value_counts(normalize=True)

# %%
resort_hotel
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# 5      Resort Hotel            0         14               2015
# 6      Resort Hotel            0          0               2015
# ...             ...          ...        ...                ...
# 40055  Resort Hotel            0        212               2017
# 40056  Resort Hotel            0        169               2017
# 40057  Resort Hotel            0        204               2017
# 40058  Resort Hotel            0        211               2017
# 40059  Resort Hotel            0        161               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2                   July                        27                          1
# ...

# %%
cancel_percent_resort_hotel
# Out:
# 0    0.717058
# 1    0.282942
# Name: is_canceled, dtype: float64

# %%
# cancel_percent_city_hotel=city_hotel_count['is_canceled'].value_counts(normalize=True)

plt.bar(['not-cancelled','cancelled'],cancel_percent_city_hotel)
plt.title('Cancel percent of City Hotel')
plt.ylabel('Percent')
# Out:
# Text(0, 0.5, 'Percent')

# %%
# cancel_percent_resort_hotel=resort_hotel_count['is_canceled'].value_counts(normalize=True)
plt.bar(['not-cancelled','cancalled'],cancel_percent_resort_hotel)
plt.title('Cancel percent of Resort Hotel')
plt.ylabel('Percent')
# Out:
# Text(0, 0.5, 'Percent')

# %%
#Finally, showed the cancellation ratio of city hotel is larger than that of Resort hotel. 
#which shows that cancellation rate of City Hotels is higher than Resort Hotel. 
#n and df are same dataframe. df is original

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2                    July                        27
# 3                    July                        27
# ...

# %%
#Checking if the price affects the cancellation of hotel booking

# %%
#city hotel is the dataframe defined above: city_hotel=n[n['hotel']='City Hotel']
avg_daily_rate_city_hot=city_hotel.groupby('reservation_status_date')['adr'].mean()

# %%
avg_daily_rate_city_hot
# Out:
# reservation_status_date
# 2014-10-17     62.800000
# 2015-01-01     62.063158
# 2015-01-20     76.500000
# 2015-01-30     61.400000
# 2015-02-17     76.500000
#                  ...
# 2017-09-03    137.172600
# 2017-09-04    116.925385
# 2017-09-05    154.000000
# 2017-09-06     93.293333
# 2017-09-07    159.685000
# Name: adr, Length: 864, dtype: float64

# %%
#finding the average daily rate of City Hotel for each date. this and above are some thing
avg_daily_rate_city_hotel=n[n['hotel']=='City Hotel'].groupby('reservation_status_date')['adr'].mean()

# %%
avg_daily_rate_city_hotel
# Out:
# reservation_status_date
# 2014-10-17     62.800000
# 2015-01-01     62.063158
# 2015-01-20     76.500000
# 2015-01-30     61.400000
# 2015-02-17     76.500000
#                  ...
# 2017-09-03    137.172600
# 2017-09-04    116.925385
# 2017-09-05    154.000000
# 2017-09-06     93.293333
# 2017-09-07    159.685000
# Name: adr, Length: 864, dtype: float64

# %%
avg_dr_city_hotel=avg_daily_rate_city_hotel.reset_index()

# %%
avg_dr_city_hotel
# Out:
#     reservation_status_date         adr
# 0                2014-10-17   62.800000
# 1                2015-01-01   62.063158
# 2                2015-01-20   76.500000
# 3                2015-01-30   61.400000
# 4                2015-02-17   76.500000
# ..                      ...         ...
# 859              2017-09-03  137.172600
# 860              2017-09-04  116.925385
# 861              2017-09-05  154.000000
# 862              2017-09-06   93.293333
# 863              2017-09-07  159.685000
#
# [864 rows x 2 columns]

# %%
avg_dr_city_hotel['reservation_status_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
n["reservation_status_date"].nunique()
# Out:
# 924

# %%
#now plotting the avg_daily_rate in graph
plt.figure(figsize=(15,5))
plt.title("Average Daily Rate of City Hotel", fontsize=20)
plt.ylabel('Average daily rate(Price($))')
avg_daily_rate_city_hotel.plot()
# Out:
# <AxesSubplot:title={'center':'Average Daily Rate of City Hotel'}, xlabel='reservation_status_date', ylabel='Average daily rate(Price($))'>

# %%
#now plotting the same avg_daily_rate in graph for city hotel but in different way
#this plt.plot() can be used for dataframe only not series
plt.figure(figsize=(15,5))
plt.title("Average Daily Rate of City Hotel", fontsize=20)
plt.ylabel('Average daily rate(Price($))')
plt.plot(avg_dr_city_hotel['reservation_status_date'],avg_dr_city_hotel['adr'])

# %%
#finding the average daily rate of Resort hotel

avg_daily_rate_resort_hotel=n[n['hotel']=='Resort Hotel'].groupby('reservation_status_date')['adr'].mean()

# %%
avg_daily_rate_resort_hotel
# Out:
# reservation_status_date
# 2015-01-01     61.966667
# 2015-01-02    154.140000
# 2015-01-21     37.301209
# 2015-01-22    116.568333
# 2015-01-28    244.000000
#                  ...
# 2017-09-08    101.012500
# 2017-09-09    147.778333
# 2017-09-10    145.272500
# 2017-09-12    153.570000
# 2017-09-14    105.930000
# Name: adr, Length: 911, dtype: float64

# %%
avg_dr_resort_hotel=avg_daily_rate_resort_hotel.reset_index()

# %%
avg_dr_resort_hotel
# Out:
#     reservation_status_date         adr
# 0                2015-01-01   61.966667
# 1                2015-01-02  154.140000
# 2                2015-01-21   37.301209
# 3                2015-01-22  116.568333
# 4                2015-01-28  244.000000
# ..                      ...         ...
# 906              2017-09-08  101.012500
# 907              2017-09-09  147.778333
# 908              2017-09-10  145.272500
# 909              2017-09-12  153.570000
# 910              2017-09-14  105.930000
#
# [911 rows x 2 columns]

# %%
plt.figure(figsize=(15,5))
plt.title("Average Daily Rate of Resort Hotel", fontsize=20)
plt.ylabel('Average daily rate(Price($))')
plt.plot(avg_dr_resort_hotel['reservation_status_date'],avg_dr_resort_hotel['adr'])

# %%
#comparing the average daily rate of city hotel and resort hotel
plt.figure(figsize=(15,5))
avg_daily_rate_city_hotel.plot(label='City Hotel')
avg_daily_rate_resort_hotel.plot(label='Resort Hotel')
plt.legend()
plt.title('Average daily rate of City hotel and Resort hotel',fontsize=12)
plt.xlabel('Reservation status date')
plt.ylabel('Avg daily rate(Price($))')
plt.show()

# %%
#making the countplot to know in which month the cancellation is more or less
# 0:not cancelled
# 1:cancelled

# %%
n['reservation_status_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
n['reservation_month']=n['reservation_status_date'].dt.month

# %%
plt.figure(figsize=(15,5))
ax=sns.countplot(x='reservation_month',hue='is_canceled',data=n)
plt.ylabel('number of reservation')
#this gives no of reservation and if it is cancelled or reserved. 1 means cancelled 0 is reserved
# Out:
# Text(0, 0.5, 'number of reservation')

# %%
# price was highest for first month.this means price has affect on cancellation. since price in january was highest 
#so cancellation on january was highest too. this proves 1st hypothesis. more cancellaion occur when prices are higher
cancelled_df=cancelled.groupby('reservation_month')['adr'].sum()

# %%
c_df=cancelled_df.reset_index()

# %%
c_df
# Out:
#     reservation_month        adr
# 0                   1  571203.57
# 1                   2  447675.76
# 2                   3  424872.56
# 3                   4  425315.23
# 4                   5  391438.08
# 5                   6  359003.34
# 6                   7  481243.01
# 7                   8  325668.43
# 8                   9  274176.33
# 9                  10  330968.87
# 10                 11  281367.90
# 11                 12  319272.65

# %%
plt.figure(figsize=(12,5))
sns.barplot(data=c_df,x='reservation_month', y='adr')
# Out:
# <AxesSubplot:xlabel='reservation_month', ylabel='adr'>

# %%
#looking whether cancel gareko adr high cha ki cancel nagareko adr high cha

# %%
n
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2                    July                        27
# 3                    July                        27
# ...

# %%
cancelled=n[n['is_canceled']==1]

# %%
c=cancelled['adr'].mean()

# %%
c
# Out:
# 105.40196891781197

# %%
not_cancelled=n[n['is_canceled']==0]

# %%
nc=not_cancelled['adr'].mean()

# %%
cancel=[c,nc]

# %%
cancel
# Out:
# [105.40196891781197, 102.59385497281082]

# %%
# plt.bar(['not canceled','canceled'],cancel,edgecolor='1',width=0.7)
plt.figure(figsize=(5,5))
plt.bar(['canceled','not canceled'],cancel,edgecolor='1', width=0.3)
plt.title('cacellation with respect to average daily rate')
plt.ylabel('average daily rate')
#here we can see the average daily rate is higher when there is cancellation and lower when there is not cancellation
# Out:
# Text(0, 0.5, 'average daily rate')

# %%
#cancellation rate based on countries

# %%
#total 177 countries so not possible to visualize all of them at once. selecting top 10 countries

# %%
#top country with highest cancellation
cancelled
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 8       Resort Hotel            1         85               2015
# 9       Resort Hotel            1         75               2015
# 10      Resort Hotel            1         23               2015
# 27      Resort Hotel            1         60               2015
# 32      Resort Hotel            1         96               2015
# ...              ...          ...        ...                ...
# 108829    City Hotel            1         25               2017
# 111355    City Hotel            1          4               2017
# 111924    City Hotel            1          7               2017
# 111925    City Hotel            1          6               2017
# 117295    City Hotel            1          0               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 8                    July                        27
# 9                    July                        27
# ...

# %%
n
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2                    July                        27
# 3                    July                        27
# ...

# %%
n.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'reservation_month'],
#       dtype='object')

# %%
df['country'].unique()
# Out:
# array(['GBR', 'PRT', 'USA', 'ESP', 'IRL', 'FRA', 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR', 'CRI',
#        'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO', 'AND',
#        'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT', 'NGA',
#        'MDV', 'VEN', 'SVK', 'AGO', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG', 'ISL',
# ...

# %%
#finding the country with most reservation cancellation
#using cancelled dataframe : cancelled=n[n['iscancelled==1']]

# %%
cancelled
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 8       Resort Hotel            1         85               2015
# 9       Resort Hotel            1         75               2015
# 10      Resort Hotel            1         23               2015
# 27      Resort Hotel            1         60               2015
# 32      Resort Hotel            1         96               2015
# ...              ...          ...        ...                ...
# 108829    City Hotel            1         25               2017
# 111355    City Hotel            1          4               2017
# 111924    City Hotel            1          7               2017
# 111925    City Hotel            1          6               2017
# 117295    City Hotel            1          0               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 8                    July                        27
# 9                    July                        27
# ...

# %%
cancelled['country'].nunique()
# Out:
# 127

# %%
cancelled_country=cancelled['country'].value_counts()[:6]

# %%
cancelled_country
# Out:
# PRT    27326
# GBR     2451
# ESP     2176
# FRA     1932
# ITA     1332
# DEU     1218
# Name: country, dtype: int64

# %%
cancelled_country.reset_index()
# Out:
#   index  country
# 0   PRT    27326
# 1   GBR     2451
# 2   ESP     2176
# 3   FRA     1932
# 4   ITA     1332
# 5   DEU     1218

# %%
#adding ; at the end of the plt.pie(); removes the representatio of plot in[.....]
plt.pie(cancelled_country, autopct='%.2f',labels=cancelled_country.index);
#we can see portugal has the highest cancellation. so the suggestion can be reduce the adr, and do some more advertisement in ptr

# %%
#find the market segment. ie how do client book hotels

# %%
n['market_segment'].unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO', 'Groups',
#        'Complementary', 'Aviation'], dtype=object)

# %%
booking_medium_whole=n['market_segment'].value_counts(normalize=True)[:6]

# %%
booking_medium_whole
# Out:
# Online TA        0.479116
# Offline TA/TO    0.203736
# Groups           0.167193
# Direct           0.104399
# Corporate        0.043042
# Aviation         0.001975
# Name: market_segment, dtype: float64

# %%
plt.pie(booking_medium_whole, autopct='%.2f',labels=booking_medium_whole.index);

# %%
booking_medium=cancelled['market_segment'].value_counts(normalize=True)[:6]

# %%
booking_medium
# Out:
# Online TA        0.471421
# Groups           0.274711
# Offline TA/TO    0.187449
# Direct           0.042983
# Corporate        0.022163
# Aviation         0.001160
# Name: market_segment, dtype: float64

# %%
plt.pie(booking_medium, autopct='%.2f',labels=booking_medium.index);
#people book through online TA . so it should be invesitaged

# %%
not_cancelled
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2                    July                        27
# 3                    July                        27
# ...

# %%
booking_medium_nc=not_cancelled['market_segment'].value_counts(normalize=True)[:6]

# %%
booking_medium_nc
# Out:
# Online TA        0.483748
# Offline TA/TO    0.213541
# Direct           0.141370
# Groups           0.102470
# Corporate        0.055611
# Aviation         0.002466
# Name: market_segment, dtype: float64

# %%
#see through which medium most reservation.
plt.pie(booking_medium_nc, autopct='%.2f',labels=booking_medium_nc.index);

# %%
#thus, most cancellation is also from oniline TA and most reservation too is from Online TA.
#this is a practice for exploratory data analysis in python using python libraries: pandas, matplotlib, seaborn.
